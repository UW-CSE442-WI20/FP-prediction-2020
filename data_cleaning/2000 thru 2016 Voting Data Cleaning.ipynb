# %% [markdown]
# # 2000 - 2016 Voting Data
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# # Flipped Data for County

# %%
# read the dataframe
df = pd.read_csv('2000_2016_voting_data_import/countypres_2000-2016.csv')

# %%
# find the winners
dfw = df.groupby(['FIPS', 'year'])['candidatevotes'].max().to_frame()
df2 = dfw.merge(df, left_on=['FIPS', 'year'], right_on=['FIPS', 'year'])
df3 = df2[df2['candidatevotes_x'] <= df2['candidatevotes_y']]
df3 = df3.copy()
df3['winner_percentage'] = df3['candidatevotes_y']/df3['totalvotes']
winners = df3[['FIPS', 'year', 'candidate', 'winner_percentage']]

# %%
# get each candidate and their party
df_cand = df[['candidate', 'party']]
df_cand = df_cand.drop_duplicates()
df_cand
# Out:
#              candidate       party
# 0              Al Gore    democrat
# 1       George W. Bush  republican
# 2          Ralph Nader       green
# 3                Other         NaN
# 12464       John Kerry    democrat
# 21815     Barack Obama    democrat
# 21816      John McCain  republican
# 31167      Mitt Romney  republican
# 40517  Hillary Clinton    democrat
# 40518     Donald Trump  republican

# %%
# get each county and the FIPS and county
df_county_info = df[['FIPS', 'county', 'state']]
df_county_info = df_county_info .drop_duplicates()
df_county_info.head()
# Out:
#       FIPS   county    state
# 0   1001.0  Autauga  Alabama
# 4   1003.0  Baldwin  Alabama
# 8   1005.0  Barbour  Alabama
# 12  1007.0     Bibb  Alabama
# 16  1009.0   Blount  Alabama

# %%
# Get the needed info and put into a weird form
# Unpack and put it into a weird form
winners2 = winners.pivot(index = 'FIPS', columns = 'year', values = 'candidate').reset_index()
winners3 =  winners.pivot(index = 'FIPS', columns = 'year', values = 'winner_percentage').reset_index()

winners4 = winners2.merge(winners3, left_on='FIPS', right_on='FIPS')

winners2 = winners4.rename(index=str, 
                   columns={
                       "2000_x": "2000_cand",
                       "2004_x": "2004_cand",
                       "2008_x": "2008_cand",
                       "2012_x": "2012_cand",
                       "2016_x": "2016_cand",
                       
                       "2000_y": "2000_percent",
                       "2004_y": "2004_percent",
                       "2008_y": "2008_percent",
                       "2012_y": "2012_percent",
                       "2016_y": "2016_percent"
                       
                   })
winners2.head()
# Out:
# year    FIPS       2000_cand       2004_cand    2008_cand     2012_cand  \
# 0     1001.0  George W. Bush  George W. Bush  John McCain   Mitt Romney
# 1     1003.0  George W. Bush  George W. Bush  John McCain   Mitt Romney
# 2     1005.0         Al Gore  George W. Bush  John McCain  Barack Obama
# 3     1007.0  George W. Bush  George W. Bush  John McCain   Mitt Romney
# 4     1009.0  George W. Bush  George W. Bush  John McCain   Mitt Romney
#
# year     2016_cand  2000_percent  2004_percent  2008_percent  2012_percent  \
# 0     Donald Trump      0.696943      0.756735      0.736136      0.726183
# 1     Donald Trump      0.723654      0.764152      0.752595      0.773583
# 2     Donald Trump      0.499086      0.547369      0.504385      0.513685
# 3     Donald Trump      0.601746      0.720000      0.724433      0.728266
# 4     Donald Trump      0.704779      0.808501      0.840195      0.864659
#
# year  2016_percent
# 0         0.727666
# 1         0.765457
# 2         0.520967
# 3         0.764032
# 4         0.893348

# %%
# rename and get the party for each year
for i in range(2000, 2020, 4):
    index = str(i) + "_cand"
    winners2 = winners2.merge(df_cand, left_on=index, right_on='candidate')
    winners2 = winners2.rename(index=str, 
                   columns={
                       "party": "party" + str(i),                 
                   })
    winners2 = winners2.drop(columns=['candidate'])

winners2.head()
# Out:
#      FIPS       2000_cand       2004_cand    2008_cand    2012_cand  \
# 0  1001.0  George W. Bush  George W. Bush  John McCain  Mitt Romney
# 1  1003.0  George W. Bush  George W. Bush  John McCain  Mitt Romney
# 2  1007.0  George W. Bush  George W. Bush  John McCain  Mitt Romney
# 3  1009.0  George W. Bush  George W. Bush  John McCain  Mitt Romney
# 4  1013.0  George W. Bush  George W. Bush  John McCain  Mitt Romney
#
#       2016_cand  2000_percent  2004_percent  2008_percent  2012_percent  \
# 0  Donald Trump      0.696943      0.756735      0.736136      0.726183
# 1  Donald Trump      0.723654      0.764152      0.752595      0.773583
# 2  Donald Trump      0.601746      0.720000      0.724433      0.728266
# 3  Donald Trump      0.704779      0.808501      0.840195      0.864659
# 4  Donald Trump      0.528899      0.591611      0.564940      0.535699
#
#    2016_percent   party2000   party2004   party2008   party2012   party2016
# 0      0.727666  republican  republican  republican  republican  republican
# 1      0.765457  republican  republican  republican  republican  republican
# 2      0.764032  republican  republican  republican  republican  republican
# 3      0.893348  republican  republican  republican  republican  republican
# 4      0.561269  republican  republican  republican  republican  republican

# %%
# store if there was a switch for this year
winners3 = winners2
for i in range(2000, 2016, 4):
    j = i + 4
    winners3['Switch_' + str(i) + "_" + str(j)] = winners3['party'+str(i)] !=  winners3['party'+str(j)]
winners3[winners3['Switch_2012_2016'] == True].head()
# len(winners3)
# Out:
#         FIPS       2000_cand       2004_cand    2008_cand     2012_cand  \
# 2423  2015.0  George W. Bush  George W. Bush  John McCain  Barack Obama
# 2424  2031.0  George W. Bush  George W. Bush  John McCain  Barack Obama
# 2425  2032.0  George W. Bush  George W. Bush  John McCain  Barack Obama
# 2426  2036.0  George W. Bush  George W. Bush  John McCain  Barack Obama
# 2427  8015.0  George W. Bush  George W. Bush  John McCain  Barack Obama
#
#          2016_cand  2000_percent  2004_percent  2008_percent  2012_percent  \
# 2423  Donald Trump      0.417888      0.653117      0.742107      0.508913
# 2424  Donald Trump      0.557586      0.629011      0.628082      0.501232
# 2425  Donald Trump      0.692524      0.581975      0.557975      0.622376
# 2426  Donald Trump      0.539179      0.610865      0.629552      0.671963
# 2427  Donald Trump      0.565046      0.555936      0.491230      0.486140
#
#       2016_percent   party2000   party2004   party2008 party2012   party2016  \
# 2423      0.506825  republican  republican  republican  democrat  republican
# 2424      0.551660  republican  republican  republican  democrat  republican
# 2425      0.503747  republican  republican  republican  democrat  republican
# 2426      0.539690  republican  republican  republican  democrat  republican
# 2427      0.479200  republican  republican  republican  democrat  republican
#
#       Switch_2000_2004  Switch_2004_2008  Switch_2008_2012  Switch_2012_2016
# 2423             False             False              True              True
# 2424             False             False              True              True
# 2425             False             False              True              True
# 2426             False             False              True              True
# 2427             False             False              True              True

# %%
winners4 = winners3
winners4 = winners4.merge(df_county_info, left_on = 'FIPS', right_on = 'FIPS') 
winners4.head()
# Out:
#      FIPS       2000_cand       2004_cand    2008_cand    2012_cand  \
# 0  1001.0  George W. Bush  George W. Bush  John McCain  Mitt Romney
# 1  1003.0  George W. Bush  George W. Bush  John McCain  Mitt Romney
# 2  1007.0  George W. Bush  George W. Bush  John McCain  Mitt Romney
# 3  1009.0  George W. Bush  George W. Bush  John McCain  Mitt Romney
# 4  1013.0  George W. Bush  George W. Bush  John McCain  Mitt Romney
#
#       2016_cand  2000_percent  2004_percent  2008_percent  2012_percent  ...  \
# 0  Donald Trump      0.696943      0.756735      0.736136      0.726183  ...
# 1  Donald Trump      0.723654      0.764152      0.752595      0.773583  ...
# 2  Donald Trump      0.601746      0.720000      0.724433      0.728266  ...
# 3  Donald Trump      0.704779      0.808501      0.840195      0.864659  ...
# 4  Donald Trump      0.528899      0.591611      0.564940      0.535699  ...
#
#     party2004   party2008   party2012   party2016 Switch_2000_2004  \
# 0  republican  republican  republican  republican            False
# 1  republican  republican  republican  republican            False
# 2  republican  republican  republican  republican            False
# 3  republican  republican  republican  republican            False
# 4  republican  republican  republican  republican            False
#
#   Switch_2004_2008  Switch_2008_2012  Switch_2012_2016   county    state
# 0            False             False             False  Autauga  Alabama
# 1            False             False             False  Baldwin  Alabama
# 2            False             False             False     Bibb  Alabama
# 3            False             False             False   Blount  Alabama
# 4            False             False             False   Butler  Alabama
#
# [5 rows x 22 columns]

# %%
winners4.to_csv("2000_2016_voting_data_export/FP_county_winners.csv")

# %% [markdown]
# # Flipped Data for State

# %%
# read the state data
df = pd.read_csv('2000_2016_voting_data_import/1976-2016-president.csv')
df.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic        office  \
# 0  1976  Alabama       AL           1         63        41  US President
# 1  1976  Alabama       AL           1         63        41  US President
# 2  1976  Alabama       AL           1         63        41  US President
# 3  1976  Alabama       AL           1         63        41  US President
# 4  1976  Alabama       AL           1         63        41  US President
#
#                  candidate                       party  writein  \
# 0            Carter, Jimmy                    democrat    False
# 1             Ford, Gerald                  republican    False
# 2           Maddox, Lester  american independent party    False
# 3  Bubar, Benjamin ""Ben""                 prohibition    False
# 4                Hall, Gus         communist party use    False
#
#    candidatevotes  totalvotes   version  notes
# 0          659170     1182850  20171015    NaN
# 1          504070     1182850  20171015    NaN
# 2            9198     1182850  20171015    NaN
# 3            6669     1182850  20171015    NaN
# 4            1954     1182850  20171015    NaN

# %%
print("Number of total elections:", (1 + (2016-1976)//4) )
print("Number of states:", len(df['state'].unique()))
# Out:
# Number of total elections: 11
# Number of states: 51

# %%
# find the winners
dfw = df.groupby(['state_po', 'year'])['candidatevotes'].max().to_frame()
df2 = dfw.merge(df, left_on=['state_po', 'year'], right_on=['state_po', 'year'])
df3 = df2[df2['candidatevotes_x'] <= df2['candidatevotes_y']]
# make sure that there's only one winner per year/state
assert(len(df3) == (11 * 51))
df3.head()
df3 = df3.copy()
df3['winner_percentage'] = df3['candidatevotes_y']/df3['totalvotes']
winners = df3[['state_po', 'year', 'candidate', 'winner_percentage']]
winners.head()
# Out:
#    state_po  year          candidate  winner_percentage
# 0        AK  1976       Ford, Gerald           0.579046
# 4        AK  1980     Reagan, Ronald           0.543482
# 9        AK  1984     Reagan, Ronald           0.666540
# 13       AK  1988  Bush, George H.W.           0.595909
# 19       AK  1992  Bush, George H.W.           0.394575

# %%
# get each candidate and their party
df_cand = df[['candidate', 'party']]
df_cand = df_cand.drop_duplicates()

df_cand = df_cand[(df_cand['party'] == 'democrat') | (df_cand['party'] == 'republican')]
df_cand.head()
# Out:
#               candidate       party
# 0         Carter, Jimmy    democrat
# 1          Ford, Gerald  republican
# 332      Reagan, Ronald  republican
# 697     Mondale, Walter    democrat
# 1019  Bush, George H.W.  republican

# %%
# Get the needed info and put into a weird form
winners = winners[winners['year'] >= 1996]
winners2 = winners.pivot(index = 'state_po', columns = 'year', values = 'candidate').reset_index()
winners3 =  winners.pivot(index = 'state_po', columns = 'year', values = 'winner_percentage').reset_index()

winners4 = winners2.merge(winners3, left_on='state_po', right_on='state_po')
winners2 = winners4.rename(index=str, 
                   columns={
                       "1996_x": "1996_cand",
                       "2000_x": "2000_cand",
                       "2004_x": "2004_cand",
                       "2008_x": "2008_cand",
                       "2012_x": "2012_cand",
                       "2016_x": "2016_cand",
                       
                       "1996_y": "1996_percent",
                       "2000_y": "2000_percent",
                       "2004_y": "2004_percent",
                       "2008_y": "2008_percent",
                       "2012_y": "2012_percent",
                       "2016_y": "2016_percent"
                       
                   })
winners2.head()
# Out:
# year state_po      1996_cand        2000_cand        2004_cand  \
# 0          AK   Dole, Robert  Bush, George W.  Bush, George W.
# 1          AL   Dole, Robert  Bush, George W.  Bush, George W.
# 2          AR  Clinton, Bill  Bush, George W.  Bush, George W.
# 3          AZ  Clinton, Bill  Bush, George W.  Bush, George W.
# 4          CA  Clinton, Bill         Gore, Al      Kerry, John
#
# year         2008_cand         2012_cand         2016_cand  1996_percent  \
# 0         McCain, John      Romney, Mitt  Trump, Donald J.      0.508013
# 1         McCain, John      Romney, Mitt  Trump, Donald J.      0.501218
# 2         McCain, John      Romney, Mitt  Trump, Donald J.      0.537364
# 3         McCain, John      Romney, Mitt  Trump, Donald J.      0.465171
# 4     Obama, Barack H.  Obama, Barack H.  Clinton, Hillary      0.510989
#
# year  2000_percent  2004_percent  2008_percent  2012_percent  2016_percent
# 0         0.586210      0.610653      0.594245      0.548016      0.512815
# 1         0.564838      0.624607      0.603169      0.605458      0.620831
# 2         0.513072      0.543060      0.587159      0.605669      0.605741
# 3         0.510211      0.548694      0.536352      0.536545      0.486716
# 4         0.534497      0.543056      0.610126      0.602390      0.617264

# %%
# rename and get the party for each year
for i in range(1996, 2020, 4):
    index = str(i) + "_cand"
    winners2 = winners2.merge(df_cand, left_on=index, right_on='candidate')
    winners2 = winners2.rename(index=str, 
                   columns={
                       "party": "party" + str(i),                 
                   })
    winners2 = winners2.drop(columns=['candidate'])

winners2.head()
# Out:
#   state_po     1996_cand        2000_cand        2004_cand     2008_cand  \
# 0       AK  Dole, Robert  Bush, George W.  Bush, George W.  McCain, John
# 1       AL  Dole, Robert  Bush, George W.  Bush, George W.  McCain, John
# 2       GA  Dole, Robert  Bush, George W.  Bush, George W.  McCain, John
# 3       ID  Dole, Robert  Bush, George W.  Bush, George W.  McCain, John
# 4       KS  Dole, Robert  Bush, George W.  Bush, George W.  McCain, John
#
#       2012_cand         2016_cand  1996_percent  2000_percent  2004_percent  \
# 0  Romney, Mitt  Trump, Donald J.      0.508013      0.586210      0.610653
# 1  Romney, Mitt  Trump, Donald J.      0.501218      0.564838      0.624607
# 2  Romney, Mitt  Trump, Donald J.      0.470157      0.549596      0.579748
# 3  Romney, Mitt  Trump, Donald J.      0.521841      0.671704      0.683909
# 4  Romney, Mitt  Trump, Donald J.      0.542907      0.580417      0.620040
#
#    2008_percent  2012_percent  2016_percent   party1996   party2000  \
# 0      0.594245      0.548016      0.512815  republican  republican
# 1      0.603169      0.605458      0.620831  republican  republican
# 2      0.522045      0.533292      0.507713  republican  republican
# 3      0.615171      0.645298      0.592614  republican  republican
# 4      0.566123      0.597113      0.566546  republican  republican
#
#     party2004   party2008   party2012   party2016
# 0  republican  republican  republican  republican
# 1  republican  republican  republican  republican
# 2  republican  republican  republican  republican
# 3  republican  republican  republican  republican
# 4  republican  republican  republican  republican

# %%
# store if there was a switch for this year
winners3 = winners2
for i in range(1996, 2016, 4):
    j = i + 4
    winners3['Switch_' + str(i) + "_" + str(j)] = winners3['party'+str(i)] !=  winners3['party'+str(j)]
winners3[winners3['Switch_2012_2016'] == True].head()
winners3 = winners3.drop_duplicates()
winners3.head()
# Out:
#   state_po     1996_cand        2000_cand        2004_cand     2008_cand  \
# 0       AK  Dole, Robert  Bush, George W.  Bush, George W.  McCain, John
# 1       AL  Dole, Robert  Bush, George W.  Bush, George W.  McCain, John
# 2       GA  Dole, Robert  Bush, George W.  Bush, George W.  McCain, John
# 3       ID  Dole, Robert  Bush, George W.  Bush, George W.  McCain, John
# 4       KS  Dole, Robert  Bush, George W.  Bush, George W.  McCain, John
#
#       2012_cand         2016_cand  1996_percent  2000_percent  2004_percent  \
# 0  Romney, Mitt  Trump, Donald J.      0.508013      0.586210      0.610653
# 1  Romney, Mitt  Trump, Donald J.      0.501218      0.564838      0.624607
# 2  Romney, Mitt  Trump, Donald J.      0.470157      0.549596      0.579748
# 3  Romney, Mitt  Trump, Donald J.      0.521841      0.671704      0.683909
# 4  Romney, Mitt  Trump, Donald J.      0.542907      0.580417      0.620040
#
#    ...   party2000   party2004   party2008   party2012   party2016  \
# 0  ...  republican  republican  republican  republican  republican
# 1  ...  republican  republican  republican  republican  republican
# 2  ...  republican  republican  republican  republican  republican
# 3  ...  republican  republican  republican  republican  republican
# 4  ...  republican  republican  republican  republican  republican
#
#   Switch_1996_2000 Switch_2000_2004 Switch_2004_2008 Switch_2008_2012  \
# 0            False            False            False            False
# 1            False            False            False            False
# 2            False            False            False            False
# 3            False            False            False            False
# 4            False            False            False            False
#
#    Switch_2012_2016
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
#
# [5 rows x 24 columns]

# %%
winners3[['state_po', 'party1996', 'party2000', 'party2004', 'party2008', 'party2012', 'party2016']]
# Out:
#    state_po   party1996   party2000   party2004   party2008   party2012  \
# 0        AK  republican  republican  republican  republican  republican
# 1        AL  republican  republican  republican  republican  republican
# 2        GA  republican  republican  republican  republican  republican
# 3        ID  republican  republican  republican  republican  republican
# 4        KS  republican  republican  republican  republican  republican
# 5        MS  republican  republican  republican  republican  republican
# 6        MT  republican  republican  republican  republican  republican
# 7        ND  republican  republican  republican  republican  republican
# 8        NE  republican  republican  republican  republican  republican
# 9        OK  republican  republican  republican  republican  republican
# 10       SC  republican  republican  republican  republican  republican
# 11       SD  republican  republican  republican  republican  republican
# 12       TX  republican  republican  republican  republican  republican
# 13       UT  republican  republican  republican  republican  republican
# 14       WY  republican  republican  republican  republican  republican
# 15       AR    democrat  republican  republican  republican  republican
# 16       AZ    democrat  republican  republican  republican  republican
# 17       KY    democrat  republican  republican  republican  republican
# 18       LA    democrat  republican  republican  republican  republican
# 19       MO    democrat  republican  republican  republican  republican
# 20       TN    democrat  republican  republican  republican  republican
# 21       WV    democrat  republican  republican  republican  republican
# 22       IN  republican  republican  republican    democrat  republican
# 23       NC  republican  republican  republican    democrat  republican
# 24       FL    democrat  republican  republican    democrat    democrat
# 25       OH    democrat  republican  republican    democrat    democrat
# 26       IA    democrat    democrat  republican    democrat    democrat
# 27       MI    democrat    democrat    democrat    democrat    democrat
# 28       PA    democrat    democrat    democrat    democrat    democrat
# 29       WI    democrat    democrat    democrat    democrat    democrat
# 30       CO  republican  republican  republican    democrat    democrat
# 31       VA  republican  republican  republican    democrat    democrat
# 32       NV    democrat  republican  republican    democrat    democrat
# 33       NM    democrat    democrat  republican    democrat    democrat
# 34       NH    democrat  republican    democrat    democrat    democrat
# 35       CA    democrat    democrat    democrat    democrat    democrat
# 36       CT    democrat    democrat    democrat    democrat    democrat
# 37       DC    democrat    democrat    democrat    democrat    democrat
# 38       DE    democrat    democrat    democrat    democrat    democrat
# 39       HI    democrat    democrat    democrat    democrat    democrat
# 40       IL    democrat    democrat    democrat    democrat    democrat
# 41       MA    democrat    democrat    democrat    democrat    democrat
# 42       MD    democrat    democrat    democrat    democrat    democrat
# 43       ME    democrat    democrat    democrat    democrat    democrat
# 44       MN    democrat    democrat    democrat    democrat    democrat
# 45       NJ    democrat    democrat    democrat    democrat    democrat
# 46       NY    democrat    democrat    democrat    democrat    democrat
# 47       OR    democrat    democrat    democrat    democrat    democrat
# 48       RI    democrat    democrat    democrat    democrat    democrat
# 49       VT    democrat    democrat    democrat    democrat    democrat
# 50       WA    democrat    democrat    democrat    democrat    democrat
#
#      party2016
# 0   republican
# 1   republican
# 2   republican
# 3   republican
# 4   republican
# 5   republican
# 6   republican
# 7   republican
# 8   republican
# 9   republican
# 10  republican
# 11  republican
# 12  republican
# 13  republican
# 14  republican
# 15  republican
# 16  republican
# 17  republican
# 18  republican
# 19  republican
# 20  republican
# 21  republican
# 22  republican
# 23  republican
# 24  republican
# 25  republican
# 26  republican
# 27  republican
# 28  republican
# 29  republican
# 30    democrat
# 31    democrat
# 32    democrat
# 33    democrat
# 34    democrat
# 35    democrat
# 36    democrat
# 37    democrat
# 38    democrat
# 39    democrat
# 40    democrat
# 41    democrat
# 42    democrat
# 43    democrat
# 44    democrat
# 45    democrat
# 46    democrat
# 47    democrat
# 48    democrat
# 49    democrat
# 50    democrat

# %%
winners4 = winners3.drop(columns=['1996_cand', '1996_percent'])
winners4.to_csv("2000_2016_voting_data_export/FP_state_winners.csv")
for c in winners4.columns:
    print(c)
# Out:
# state_po
# 2000_cand
# 2004_cand
# 2008_cand
# 2012_cand
# 2016_cand
# 2000_percent
# 2004_percent
# 2008_percent
# 2012_percent
# 2016_percent
# party1996
# party2000
# party2004
# party2008
# party2012
# party2016
# Switch_1996_2000
# Switch_2000_2004
# Switch_2004_2008
# Switch_2008_2012
# Switch_2012_2016

# %% [markdown]
# Here are the states that flopped in the 2016 election that we need to look for polling data on

# %%
winners4[winners4['Switch_2012_2016']][['state_po', 'party2016']]
# Out:
#    state_po   party2016
# 24       FL  republican
# 25       OH  republican
# 26       IA  republican
# 27       MI  republican
# 28       PA  republican
# 29       WI  republican
